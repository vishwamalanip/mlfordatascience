# %% [markdown]
# # Logistic Regression Binary Classification | Logistic Regression multiclass Classification

# %% [markdown]
# # Logistic Regression Binary Classification

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt #or (import matplotlib.pyplot as plt )

# %%
var = pd.DataFrame({"age":[21,45,32,41,20,35,20,23,42,34,24,22,23,25,43,44,25,30,31],"bought_insurance":['no','yes','yes','yes','no','yes','no','no','yes','yes','no','no','no','no','yes','yes','no','yes','yes']})
var
# Out:
#     age bought_insurance
# 0    21               no
# 1    45              yes
# 2    32              yes
# 3    41              yes
# 4    20               no
# 5    35              yes
# 6    20               no
# 7    23               no
# 8    42              yes
# 9    34              yes
# 10   24               no
# 11   22               no
# 12   23               no
# 13   25               no
# 14   43              yes
# 15   44              yes
# 16   25               no
# 17   30              yes
# 18   31              yes

# %%
var['bought_insurance'].replace({'no':'0','yes':'1'},inplace=True)

# %%
var
# Out:
#     age bought_insurance
# 0    21                0
# 1    45                1
# 2    32                1
# 3    41                1
# 4    20                0
# 5    35                1
# 6    20                0
# 7    23                0
# 8    42                1
# 9    34                1
# 10   24                0
# 11   22                0
# 12   23                0
# 13   25                0
# 14   43                1
# 15   44                1
# 16   25                0
# 17   30                1
# 18   31                1

# %%
plt.scatter(x='age',y='bought_insurance',data=var)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(var['age'],var['bought_insurance'],test_size=0.2)

# %%
x_train=pd.DataFrame(x_train)

# %%
y_train=pd.DataFrame(y_train)

# %%
x_test=pd.DataFrame(x_test)

# %%
y_test=pd.DataFrame(y_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /Users/vishwamalani/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['1', '1', '0', '0'], dtype=object)

# %%
x_test
# Out:
#     age
# 3    41
# 9    34
# 10   24
# 11   22

# %% [markdown]
# # Logistic Regression multiclass Classification

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt #or (import matplotlib.pyplot as plt )

# %%
var = pd.read_csv('iris.csv')
var
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
var['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
var['species'].replace({'setosa':'1','versicolor':'2','virginica':'3'},inplace=True)

# %%
var
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.5           1.4          0.2       1
# 1             4.9          3.0           1.4          0.2       1
# 2             4.7          3.2           1.3          0.2       1
# 3             4.6          3.1           1.5          0.2       1
# 4             5.0          3.6           1.4          0.2       1
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       3
# 146           6.3          2.5           5.0          1.9       3
# 147           6.5          3.0           5.2          2.0       3
# 148           6.2          3.4           5.4          2.3       3
# 149           5.9          3.0           5.1          1.8       3
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(var[['sepal_length','sepal_width','petal_length','petal_width']],var['species'],test_size=0.2)

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /Users/vishwamalani/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['2', '2', '1', '3', '3', '1', '1', '1', '2', '2', '3', '2', '1',
#        '2', '1', '1', '1', '2', '2', '2', '3', '1', '1', '3', '3', '2',
#        '3', '3', '3', '3'], dtype=object)

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 97            6.2          2.9           4.3          1.3
# 60            5.0          2.0           3.5          1.0
# 4             5.0          3.6           1.4          0.2
# 103           6.3          2.9           5.6          1.8
# 149           5.9          3.0           5.1          1.8
# 25            5.0          3.0           1.6          0.2
# 6             4.6          3.4           1.4          0.3
# 29            4.7          3.2           1.6          0.2
# 69            5.6          2.5           3.9          1.1
# 62            6.0          2.2           4.0          1.0
# 120           6.9          3.2           5.7          2.3
# 99            5.7          2.8           4.1          1.3
# 1             4.9          3.0           1.4          0.2
# 51            6.4          3.2           4.5          1.5
# 46            5.1          3.8           1.6          0.2
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
sns.pairplot(var[['sepal_length','sepal_width','petal_length','petal_width','species']],hue='species')
# Out:
# /Users/vishwamalani/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
